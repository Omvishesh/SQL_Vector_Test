# %%
from utils_sql import classify_query

# %%
from utils_sql import file_selector_worker_surveys , file_selector_finance_and_industry

# %%
query = "How did the total number of investor accounts and the total demat custody value with NSDL evolve up to August 31, 2024, and what major operational or organizational milestone (such as the inauguration of the new corporate office or regulatory recognition) was announced in the latest press releases during the same period?"

# %%
query_class, i_token, o_token = classify_query(query)

# %%
print(query_class)
# Out:
# finance_and_industry

# %%
query = "What was the quarterly trend for the following macroeconomic variable : Employment levels Average labour productivity in the Indian unincorporated sector (for January–June 2025)"

# %%
query_class = "worker_surveys"

# %%
if (query_class == "worker_surveys"):
        selected_file, i_tokens, o_tokens = file_selector_worker_surveys(query)
        # total_input_tokens['gpt-4.1'] += i_tokens
        # total_output_tokens['gpt-4.1'] += o_tokens

if (query_class == "finance_and_industry"):
        selected_file, i_tokens, o_tokens = file_selector_finance_and_industry(query)

# %%
print(selected_file)
# Out:
# none_of_these
